# %%
# %load_ext autoreload
# %autoreload 2
# %env ANYWIDGET_HMR=1
import molpy as mp
import molvis as mv
import numpy as np

import logging
logging.basicConfig(level=logging.INFO)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# env: ANYWIDGET_HMR=1

# %%
tfsi = mp.io.read_pdb('./LiTFSI.pdb')
tfsi.frame['atoms']
# Out:
#     id name resName chainID  resSeq      x      y      z element
# 0    1    F     TFS               1  3.540  1.420  0.000       F
# 1    2    C     TFS               1  3.733  1.147  1.324       C
# 2    3   F1     TFS               1  4.220  2.304  1.870       F
# 3    4   F2     TFS               1  2.506  1.019  1.830       F
# 4    5    S     TFS               1  4.869 -0.260  1.597       S
# 5    6    O     TFS               1  4.960 -0.407  3.055       O
# 6    7   O3     TFS               1  4.239 -1.399  0.931       O
# 7    8    N     TFS               1  6.132  0.358  0.945       N
# 8    9   S1     TFS               1  6.832 -0.585 -0.109       S
# 9   10   O1     TFS               1  7.791 -1.548  0.441       O
# 10  11   O2     TFS               1  6.009 -1.089 -1.208       O
# 11  12   C1     TFS               1  7.851  0.721 -0.881       C
# 12  13   F4     TFS               1  8.746  0.244 -1.792       F
# ...

# %%
canvas = mv.Molvis()
# Out:
# Molvis(session_id=140673711566976)

# %%
canvas
# Out:
# Molvis(session_id=140673711566976)
